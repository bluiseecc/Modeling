# %% [markdown]
# Product idea: Spatial and temporal optimizer for production asset managers (When and where to produce?)
#
# Min sum( Costv-i + Costf-i) where i is the production site
#
# And Costv-i = Price*Consumption, consumption as a function of production
#
# ![image.png](attachment:image.png)
